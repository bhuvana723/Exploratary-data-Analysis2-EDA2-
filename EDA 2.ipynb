# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/adult_with_headers.csv')
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Print the available columns in the DataFrame to check for the correct column name
print(df.columns)

# Replace 'native-country' with the actual name if it's different
for column in ['workclass', 'occupation', 'native_country']:  # Check spelling!
    # If the column exists, fill NaN values with the mode
    if column in df.columns:
        df[column].fillna(df[column].mode()[0], inplace=True)
    else:
        print(f"Column '{column}' not found in DataFrame.")
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
numerical_features = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
numerical_features = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
numerical_features = [col.replace('-', '_') for col in numerical_features]
print(df.columns)
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
categorical_features = ['workclass', 'education', 'marital-status', 'occupation',
                         'relationship', 'race',  'native-country']

# %%
categorical_features = df.select_dtypes(include=['object']).columns.tolist()

low_cardinality_features = []
for feature in categorical_features:
    if df[feature].nunique() < 5:
        low_cardinality_features.append(feature)

print(low_cardinality_features)
# Out:
# ['sex', 'income']

# %%
df = pd.get_dummies(df, columns=low_cardinality_features, drop_first=True)

# %%
df
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# ...

# %%
categorical_features = df.select_dtypes(include=['object']).columns.tolist()

high_cardinality_features = []
for feature in categorical_features:
    if df[feature].nunique() > 5:
        high_cardinality_features.append(feature)

print(high_cardinality_features)  # This will print the selected features
# Out:
# ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'native_country']

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
for feature in high_cardinality_features:
    df[feature] = label_encoder.fit_transform(df[feature])

# %%
df
# Out:
#             age  workclass    fnlwgt  education  education_num  \
# 0      0.301370          7  0.044302          9       0.800000
# 1      0.452055          6  0.048238          9       0.800000
# 2      0.287671          4  0.138113         11       0.533333
# 3      0.493151          4  0.151068          1       0.400000
# 4      0.150685          4  0.221488          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          4  0.166404          7       0.733333
# 32557  0.315068          4  0.096500         11       0.533333
# 32558  0.561644          4  0.094827         11       0.533333
# 32559  0.068493          4  0.128499         11       0.533333
# 32560  0.479452          5  0.187203         11       0.533333
#
#        marital_status  occupation  relationship    race      sex  \
# 0                   4           1             1   White     Male
# 1                   2           4             0   White     Male
# ...

# %%
df['financial_dependency_ratio'] = (df['capital_gain'] - df['capital_loss']) / df['fnlwgt']

# %%
df['work_experience_years'] = df['age'] - (df['education_num'] + 6)
df['work_experience_years'] = df['work_experience_years'].clip(lower=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df['capital_gain'], kde=True)
plt.show()
skewness = df['capital_gain'].skew()
print(f"Skewness of capital_gain: {skewness}")
# Out:
# Skewness of capital_gain: 11.953847687699781

# %%
df['capital_gain_log'] = np.log1p(df['capital_gain'])

# %%
from sklearn.ensemble import IsolationForest

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import IsolationForest
from sklearn.impute import SimpleImputer

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Get a list of categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Encode categorical features using Label Encoding
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# Now, apply SimpleImputer to the DataFrame with only numerical features
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

isolation_forest = IsolationForest(contamination=0.05, random_state=42)
isolation_forest.fit(df_imputed)
# Out:
# IsolationForest(contamination=0.05, random_state=42)

# %%
# Get outlier predictions (-1 for outliers, 1 for inliers)
# Use the imputed DataFrame (df_imputed) for prediction
outlier_predictions = isolation_forest.predict(df_imputed)

# Filter the original DataFrame (df) based on predictions made on the imputed DataFrame
df = df[outlier_predictions == 1]

# %%
# !pip install ppscore==1.3.0

# %%
import pandas as pd
import ppscore as pps
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import IsolationForest
from sklearn.impute import SimpleImputer

# ... (Your existing code for label encoding, imputation, and outlier removal) ...

# Calculate PPS matrix
pps_matrix = pps.matrix(df)

# Convert 'x' and 'y' columns to numeric if they are of type object
pps_matrix['x'] = pd.to_numeric(pps_matrix['x'], errors='ignore')
pps_matrix['y'] = pd.to_numeric(pps_matrix['y'], errors='ignore')

# Convert the 'ppscore' column to numeric if it's not already
pps_matrix['ppscore'] = pd.to_numeric(pps_matrix['ppscore'], errors='coerce')

# Drop rows with NaN values after conversion, if any
pps_matrix = pps_matrix.dropna()

# Check if the DataFrame is empty before creating the heatmap
if pps_matrix.empty:
    print("PPS matrix is empty. Cannot create heatmap.")
else:
    # Now, create the heatmap
    heatmap_data = pps_matrix.pivot(index='x', columns='y', values='ppscore')
    sns.heatmap(heatmap_data, annot=True, cmap='viridis')
    plt.show()
